# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

path='ex1data1.txt'
data=pd.read_table(path,sep=',',names=['HouseSize','Price'])
# data.plot(kind='scatter',x='HouseSize',y='Price',figsize=(12,8))
# plt.show()
data.insert(0,'Ones',1)
cols=data.shape[1]
x=data.iloc[:,0:cols-1]
y=data.iloc[:,cols-1:cols]
x=np.mat(x.values)
y=np.mat(y.values)

#weight matrix
w=np.mat(np.random.rand(2,1))

'''
def cost_function(x,y,w):
    return np.square(x.dot(w)-y).sum()/(2*np.size(x))
'''
learning_rate=1e-2 #0.01
iters=50000

for i in range(iters):
    h=x.dot(w)-y
    w=w-(learning_rate/np.size(x))*(np.multiply(h,x).sum(axis=0)).T

x = np.linspace(data.HouseSize.min(), data.HouseSize.max(), 100)

w=w.T
f = w[0, 0] + (w[0, 1]*x)
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(x, f, 'r', label='Predict')
ax.scatter(data.HouseSize, data.Price, label='Traning Data')
ax.legend(loc=2)
ax.set_xlabel('House Size')
ax.set_ylabel('Price')
ax.set_title('Predicted Price vs. House Size')
plt.show()
